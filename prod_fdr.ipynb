# %%
import datetime as dt
from etl_tool import FdrBroker, FdrExtractor, FdrOhlcvPreproc

# %%
fdr_broker =  FdrBroker()
fdr_extractor = FdrExtractor(fdr_broker)
fdr_extractor

# %%
krx_df = fdr_extractor.extract_krx_df()
krx_df
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          77500          2
# 1     000660  KR7000660001    SK하이닉스  KOSPI         175100          2
# 2     373220  KR7373220003  LG에너지솔루션  KOSPI         368000          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         778000          2
# 4     005935  KR7005931001     삼성전자우  KOSPI          65000          2
# ...      ...           ...       ...    ...    ...     ...        ...
# 2798  217320  KR7217320001       썬테크  KONEX  일반기업부    2500          0
# 2799  413300  KR7413300005   티엘엔지니어링  KONEX  일반기업부    1995          2
# 2800  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1640          2
# 2801  308700  KR7308700004       테크엔  KONEX  일반기업부     199          0
# 2802  322190  KR7322190000        베른  KONEX  일반기업부      30          1
#
#       Changes  ChagesRatio    Open    High     Low    Volume        Amount  \
# 0       -2100        -2.64   78300   78700   77300  11162982  869152018800
# 1       -7200        -3.95  177200  178500  173600   1888936  331937160650
# 2       -9000        -2.39  372000  372000  366500     45905   16915650000
# 3      -12000        -1.52  784000  789000  777000     14038   10947147000
# 4       -1300        -1.96   65900   66000   64800    404588   26442866200
# ...       ...          ...     ...     ...     ...       ...           ...
# 2798        0         0.00       0       0       0         0             0
# 2799     -105        -5.00    2350    2400    1785       106        192466
# 2800       -9        -0.55    1640    1640    1640         1          1640
# 2801        0         0.00       0       0       0         0             0
# 2802       14        87.50      13      30      13     97650       2314233
#
#                Marcap      Stocks MarketId
# 0     462658147625000  5969782550      STK
# 1     127473214111500   728002365      STK
# 2      86112000000000   234000000      STK
# 3      55373372000000    71174000      STK
# 4      53487635500000   822886700      STK
# ...               ...         ...      ...
# 2798       2625000000     1050000      KNX
# 2799       2604502425     1305515      KNX
# 2800       2591134400     1579960      KNX
# 2801        796000000     4000000      KNX
# 2802        267755910     8925197      KNX
#
# [2803 rows x 17 columns]

# %%
kospi_df = krx_df[krx_df['Market'] == 'KOSPI']
kosdaq_df = krx_df[krx_df['Market'] == 'KOSDAQ']

# %%
kospi_stock_codes =  list(set(kospi_df['Code']))
kosdaq_stock_codes =  list(set(kosdaq_df['Code']))

# %%
end_date = dt.date.today()
start_date = end_date - dt.timedelta(days=365 * 5)

# %%
kospi_ohlcv_df = fdr_extractor.extract_multi_ohlcv_df(
    kospi_stock_codes, start_date, end_date
)
# Out:
#   0%|          | 0/954 [00:00<?, ?it/s]
# 100%|██████████| 954/954 [02:14<00:00,  7.08it/s]

# %%
kosdaq_ohlcv_df = fdr_extractor.extract_multi_ohlcv_df(
    kosdaq_stock_codes, start_date, end_date
)
# Out:
# 100%|██████████| 1676/1676 [03:10<00:00,  8.78it/s]

# %%
fdr_ohlcv_preproc = FdrOhlcvPreproc()

# %%
kospi_ohlcv_df_ = fdr_ohlcv_preproc(kospi_ohlcv_df)
kosdaq_ohlcv_df_ = fdr_ohlcv_preproc(kosdaq_ohlcv_df)

# %%
kospi_ohlcv_df_.to_csv("./data/fdr/kospi_ohlcv_df.csv")
kosdaq_ohlcv_df_.to_csv("./data/fdr/kosdaq_ohlcv_df.csv")
